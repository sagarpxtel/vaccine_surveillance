# %%
import copy
import json


class TweetTagger:
    def __init__(self):
        self.tweets = []
        self.labels = []
        
    def load(self, tweets_filename):
        with open(tweets_filename) as json_file:
            for line in json_file:
                data_obj = json.loads(line)
                if len(self.tweets) >= 10:
                    break
                self.tweets.append(data_obj)
                self.labels.append("")
    
    def label_tweets(self):
        total_tweets = len(self.tweets)
        for i in range(total_tweets):
            tweet = self.tweets[i]['text']
            
            if 'extended_tweet' in self.tweets[i]:
                multi_line_tweet = self.tweets[i]['extended_tweet']['full_text']
                tweet = "".join(multi_line_tweet.splitlines())
            
            answer = input(f'{tweet}: Positive or Negative: ')
            self.labels[i] = answer
            
    def count(self, label):
        counter = 0
        for tag in self.labels:
            if tag == label:
                counter += 1   
        return counter

    def trim(self, label, count):
        new_tweets = []
        new_labels = []
        total_tweets = len(self.tweets)
        
        label_count = self.count(label)
        remove_bool = label_count > count
        
        for i in range(total_tweets):
            if remove_bool and label == self.labels[i]:
                continue
            if self.tweets[i]['lang'] == 'en':
                new_tweets.append(self.tweets[i])
                new_labels.append(self.labels[i])
      
        self.tweets = new_tweets
        self.labels = new_labels

    def merge(self, another_tweet_tagger):
        new_tweets = another_tweet_tagger.tweets
        new_labels = another_tweet_tagger.labels
        self.tweets.extend(new_tweets)
        self.labels.extends(new_labels)
        

    def save(self, filename):
        with open(f'tweets_{filename}.txt', 'w') as outfile:
            for tweet in self.tweets:
                outfile.write(f'{tweet}\n')
        
        with open(f'labels_{filename}.txt', 'w') as outfile:
            for label in self.labels:
                outfile.write(f'{label}\n')
            


t = TweetTagger()
t.load("test.json")
t.label_tweets()

# text = t.tweets[21]['quoted_status']['extended_tweet']['full_text']
# s_text = "".join(text.splitlines())
# print(s_text)

# t.save('vaccine')
# Out:
# RT @JeremyScheel1: Stay diligent with masking and if you're not vaccinated, please reconsider. UK has been an accurate enough predictor for…: Positive or Negative: pos
# RT @EmeraldRobinson: Remember when I told you the vaccinated would start getting sick?
#
# Now the British Government is confirming it.: Positive or Negative: s
# Biden Mocks Vaccine Skeptics: 'I Have the Freedom to Kill You With My COVID'
# https://t.co/qbnzeI4byF: Positive or Negative: s
# RT @BoSnerdley: Arizona seeks temporary restraining order to stop Biden vaccine mandate https://t.co/y3r7hl7fJz #FoxNews: Positive or Negative: s
# RT @HannaFlint: Between this, the Ruby Rose allegations, and the IATSE strikes, Hollywood execs needs to be making some major work and safe…: Positive or Negative: ss
# #WashingtonFootball injury statuses at the PackersOUTOT Sam Cosmi-ankleG Brandon Scherff-kneeWR Curtis Samuel-groinWR Cam Sims-hamstringQUESTIONABLERB Antonio Gibson-shinCB William Jackson III-kneeDE Shaka Toney-illness#FPC #NFL #WASvsGB: Positive or Negative:
# @A_dmg04 Brutal. That shit is like death warmed over.: Positive or Negative: s
# RT @DanielDiMartino: This is how we end cancel culture. Great job @realDailyWire for hiring Allison.
#
# This type of action reduces the cost…: Positive or Negative:
# Death to America (the government the people are cool I guess :/): Positive or Negative: s
# RT @drsimonegold: MUST WATCH: General Electric employees walk off the job to protest against vaccine mandates.
#
# Do not quit your job over m…: Positive or Negative: s
